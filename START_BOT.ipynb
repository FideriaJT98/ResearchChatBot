# %%
#==============================================================================

# %%
const profile_url ="http://fci.nust.na/"
# Out:
# "http://fci.nust.na/"

# %%
fci_URL = "http://fci.nust.na"
eng_URL = "http://fe.nust.na"
health_URL = "http://fhas.nust.na"
human_sc_URL = "http://fhs.nust.na"
manage_URL = "http://fms.nust.na"
natural_URL = "http://fnrss.nust.na"
# Out:
# "http://fnrss.nust.na"

# %%
baseURL = string(fci_URL, "/?q=list-all-staff")
# Out:
# "http://fci.nust.na/?q=list-all-staff"

# %%
include("utilities/Staff.jl")
# Out:
# Main.Staff

# %%
#==============================================================================
# Out:
# syntax: incomplete: unterminated multi-line comment #= ... =#

# %%
using Genie.Router

# %%
using Genie

# %%
using HTTP, Gumbo, Cascadia

# %%
using Genie.Requests

# %%
using TextAnalysis, WordTokenizers

# %%
using JSON

# %%
using PyCall

# %%
@pyimport nltk.tag as ptag
# Out:
# ┌ Warning: `@pyimport foo` is deprecated in favor of `foo = pyimport("foo")`.
# │   caller = _pywrap_pyimport(::PyObject) at PyCall.jl:399
# └ @ PyCall C:\Users\Dell Pro\.julia\packages\PyCall\zqDXB\src\PyCall.jl:399

# %%
@pyimport nltk.sentiment.vader as Sentiment

# %%
route("/", named = :root) do
    Router.serve_static_file("/bot.html")
end
# Out:
# [GET] / => #3 | :root

# %%
function get_noun(x)
    for t in x
        if t[2] == "NN" || t[2] == "NNP"
            println(t[1])
            return string(t[1])             
        end
    end
end

function rebuild(z)
    cnt = 1
    sentence = ""
    for i in z
        if cnt == 1
            sentence = string(sentence, i)
            cnt = cnt+1
        else
            sentence = string(sentence, " ", i)
            cnt = cnt+1
        end
    end
    return sentence
end

function get_mood(sentence)
    sid = Sentiment.SentimentIntensityAnalyzer()
    scores = sid.polarity_scores(sentence)
    println(scores)
    if scores["neg"] > .5 
        return "negative"
    elseif (scores["pos"] > .5) && (scores["neg"] <= 1)
        return "positive"
    elseif  scores["neu"] == 1
        return "neutral"
    end 
end
# Out:
# get_mood (generic function with 1 method)

# %%
route("/pass_val", method=POST, named = :randommap) do
    text_dirty = @params(:human)
    
    var = split(lowercase(string(text_dirty)) ,r"[_]")
    z = String.(var)                 
    x = ptag.pos_tag(z)
    
    text_clean = rebuild(z)    
    mood = get_mood(text_clean)
    
    type_res = "mood"
    alt_value = "mood"
    #res = JSON.json(Dict(:type => type_res, :alt => alt_value, :info => mood))
    
    
    println(x)
    
    person_name = ""
    person_name = get_noun(x)    
    println(person_name)
    
    link, title, name = Staff.search_staff(string(person_name), baseURL,"1")
    
    alt_value = string(title, " ", name)
        
    image_link = "$profile_url$link"
    r = HTTP.request("GET", image_link; verbose=3)
    h = parsehtml(String(r.body))
    qs = eachmatch(sel".user-picture img", h.root)
    
    image = getattr(qs[1], "src")
    type_res = "image"
    
    res = JSON.json(Dict(:type => type_res, :alt => alt_value, :info => image))
    println(res)
    
    "$res"
end
# Out:
# [POST] /pass_val => #5 | :randommap

# %%
up()
# Out:
# Web Server starting at http://127.0.0.1:8000
# Web Server running at http://127.0.0.1:8000
# Genie.AppServer.ServersCollection(Task (runnable) @0x000000002637c010, nothing)
# ┌ Info: / 200
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:148
# ┌ Error: /css/img/genie/bg2.png 404
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:150
# ┌ Error: /css/fonts/fontawesome-webfont.woff2?v=4.7.0 404
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:150
# ┌ Error: /css/fonts/fontawesome-webfont.woff?v=4.7.0 404
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:150
# ┌ Error: /css/fonts/fontawesome-webfont.ttf?v=4.7.0 404
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:150
# Dict{Any,Any}("neg" => 0.0,"neu" => 1.0,"pos" => 0.0,"compound" => 0.0)
# [("who", "WP"), ("is", "VBZ"), ("mr", "JJ"), ("quenum", "NN")]
# quenum
# quenum
# DEBUG: 2020-04-25T02:08:54.492 1ed5 ➡️  "7169843247631136110810511511645971081084511511697102102327284848047494649131072111115116583210299105461101171151164611097131085115101114456510310111011658327284848046106108474946524648131067111110116101110116457610111010311610458324813101310" (write)
# DEBUG: 2020-04-25T02:08:55.154 1ed5 ⬅️  "HTTP/1.1 200 OK\r\n" (readuntil)
# DEBUG:                                 "Date: Sat, 25 Apr 2020 00:08:53 GMT\r\n"
# DEBUG:                                 "Server: Apache/2.4.7 (Ubuntu) mod_fastcgi/mod_fastcgi-SNAP-0910052141 mod_fcgid/2.3.9 mod_python/3.3.1 Python/2.7.6 OpenSSL/1.0.1f mod_perl/2.0.8 Perl/v5.18.2\r\n"
# DEBUG:                                 "Expires: Sun, 19 Nov 1978 05:00:00 GMT\r\n"
# DEBUG:                                 "Cache-Control: no-cache, must-revalidate\r\n"
# DEBUG:                                 "X-Content-Type-Options: nosniff\r\n"
# DEBUG:                                 "Content-Language: en\r\n"
# DEBUG:                                 "X-Frame-Options: SAMEORIGIN\r\n"
# DEBUG:                                 "X-Generator: Drupal 7 (http://drupal.org)\r\n"
# DEBUG:                                 "Vary: Accept-Encoding\r\n"
# DEBUG:                                 "X-Mod-Pagespeed: 1.13.35.2-0\r\n"
# DEBUG:                                 "Cache-Control: max-age=0, no-cache, s-maxage=10\r\n"
# DEBUG:                                 "Transfer-Encoding: chunked\r\n"
# DEBUG:                                 "Content-Type: text/html; charset=utf-8\r\n"
# DEBUG:                                 "\r\n"
# DEBUG: 2020-04-25T02:08:55.194 1ed5 ⬅️  "12f4c\r\n" (readuntil)
# DEBUG: 2020-04-25T02:08:55.572 1ed5 ⬅️  "<!doctype html>\n" (unsafe_read)
# DEBUG:                                 "<html lang=\"en\" dir=\"ltr\">\n"
# DEBUG:                                 "<head>\n"
# DEBUG:                                 "  <meta http-equiv=\"Content-Type\" content=\"text/html; charset=utf-8\"/>\n"
# DEBUG:                                 "<link rel=\"shortcut icon\" href=\"http://fci.nust.na/sites/default/files/xnust-shield.png.pagespeed.ic.YMr3eoVZMD.png\" type=\"image/png\"/>\n"
# DEBUG:                                 "<meta name=\"Generator\" content=\"Drupal 7 (http://drupal.org)\"/>\n"
# DEBUG:                                 "  <title>Staff | Faculty of Computing and Informatics</title>\n"
# DEBUG:                                 "  <meta name=\"viewport\" content=\"width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no\"/>\n"
# DEBUG:                                 "  <meta name=\"HandheldFriendly\" content=\"true\"/>\n"
# DEBUG:                                 "  <meta name=\"apple-touch-fullscreen\" content=\"YES\"/>\n"
# DEBUG:                                 "  <meta http-equiv=\"X-UA-Compatible\" content=\"IE=edge\"/>\n"
# DEBUG:                                 "  <meta name=\"viewport\" content=\"width=device-width, initial-scale=1\"/>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "  <link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/A.css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css+css_IoO0RXUhndl-0J25myNQNYp91mQgES4ykf1Z2ePa7QE.css+css_Wvx69yhFdFBmmlrnemSBfnf7QPBiSNR1Z8wpWOmbFpY.css,Mcc.UVw33HbwGj.css.pagespeed.cf.B13FLrixvb.css\" media=\"all\"/>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"//cdn.jsdelivr.net/qtip2/2.2.1/jquery.qtip.min.css\" media=\"all\"/>\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/A.css_b_jnRW2AgnbyYTrIWoXZ5VoXckWuMj8cLgs-Rw44KPY.css.pagespeed.cf.XfpwkSaQX4.css\" media=\"all\"/>\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/A.css_mVTVe3QDcYy2yv2dYapzOpY2oPmdzHD9rJjOulHJqeo.css.pagespeed.cf.BPKRi6-SXe.css\" media=\"all\"/>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<!--[if lt IE 9]>\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/css_b8aLHIO7noS6cRI-HT5RqIcwselU4KHSfIhqhv1rl8g.css\" media=\"all\" />\n"
# DEBUG:                                 "<![endif]-->\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<!--[if IE 9]>\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/css_neGToSXucSf9eIPb6PK7cb2bzF5VRIND9XeRfN7Ej6E.css\" media=\"all\" />\n"
# DEBUG:                                 "<![endif]-->\n"
# DEBUG:                                 "<style media=\"only screen and (min-width:992px) and (max-width:1199px)\">h1,h2,h1#page-title{font-size:1.385em}.view-metro .views-metro-item{height:280px}.view-campus-slideshow .views-slideshow-controls-bottom{bottom:0}.view-campus-slideshow .views-slideshow-controls-bottom .views_slideshow_pager_field_item{padding:5px 10px 5px 25px}.view-hot-course .views-fieldset{padding:12px 0}.view-hot-course .views-field-title a{font-size:1.154em}.view-hot-course .views-field-name{font-size:1.538em;margin-bottom:5px}.view-slide-accordian div.views_horizontal_slider div.item-list li.hslider-active{width:70%}.view-slide-accordian div.views_horizontal_slider div.item-list li{width:10%!important}.view-slide-accordian div.views_horizontal_slider div.item-list li .views-fieldset{width:100%}.view-slide-accordian div.views_horizontal_slider div.item-list li.open{width:70%!important}.view-courses .view-filters input.form-text{max-width:172px}.sidebar .views-field-title a{font-size:1.077em}.view-home-testimonial .flexslider .views-field-field--class{padding-left:60px}.social-links .views-field,.social-links .field,.group-social-networks .views-field,.group-social-networks .field{padding:0 6px}</style>\n"
# DEBUG:                                 "<style media=\"only screen and (max-width:991px)\">body{-webkit-text-size-adjust:100%;-webkit-font-smoothing:antialiased}html{-webkit-font-smoothing:antialiased;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.affix{position:static}.view-slide-accordian div.views_horizontal_slider div.item-list li.hslider-active{width:70%}.view-slide-accordian div.views_horizontal_slider div.item-list li{width:10%!important}.view-slide-accordian div.views_horizontal_slider div.item-list li .views-fieldset{width:100%}.view-slide-accordian div.views_horizontal_slider div.item-list li.open{width:70%!important}.view-intro .views-field-field-image{float:none;margin-bottom:20px;margin-right:0;max-width:none}.view-intro .views-field-field-image img{width:100%}.not-front .sidebar{padding-top:0}</style>\n"
# DEBUG:                                 "<style media=\"only screen and (min-width:768px) and (max-width:991px)\">.front #page{padding-top:375px}.front #content{margin-bottom:90px!important}.front .header{height:60px}.front .header:before,.front .header:after{bottom:-70px;height:70px}.header .block-menu{bottom:-40px}.header .block-lang-dropdown{bottom:-45px}.view-metro .views-metro-item{height:auto;width:50%}.view-metro .views-metro-item:first-child{width:100%}.view-metro .views-metro-item:first-child .item-inner{margin:0 15px}.view-metro .views-metro-item .views-field-field-image img{height:auto}.view-metro .views-metro-item .item-inner{margin:0 15px}.view-services .views-col{padding:0 30px;width:50%!important}.view-campus-slideshow .views-slideshow-controls-bottom{bottom:0}.view-campus-slideshow .views-slideshow-controls-bottom .views_slideshow_pager_field_item{padding:5px 10px 5px 25px}#panel-second .panel-column{width:50%}#panel-second .panel-column:first-child{margin-bottom:20px;width:100%}#panel-second .panel-column:first-child img{float:left;margin-right:20px}.profile .group-user-info,.profile .user-picture{width:33%}.profile .group-user-description{margin-top:-33%;width:65%}.profile .group-social-networks .field{padding:0 5px}.social-links .views-field,.social-links .field{padding:0 2px}.view-jcarousel .jcarousel-skin-default .views-field-field-full-name{font-size:1.077em}.view-jcarousel .jcarousel-skin-default .views-field-field-user-description{font-size:.923em}.view-images .views-col .views-field-field-full-name{font-size:1em}.view-images .views-col .views-field-field--class{font-size:.923em}.view-slide-accordian div.views_horizontal_slider div.item-list li img{max-height:237px}.view-slide-accordian div.views_horizontal_slider div.item-list li.open img{max-width:100%}.view-slide-accordian div.views_horizontal_slider div.item-list .views-field-description{font-size:1.077em}.view-hot-course .views-field-field-description{display:none}.view-hot-course .views-field-title a{font-size:1.077em}.view-hot-course .views-field-name{font-size:1.538em}</style>\n"
# DEBUG:                                 "<link type=\"text/css\" rel=\"stylesheet\" href=\"http://fci.nust.na/sites/default/files/css/A.css__0VM6UYacWc-N7n8fDWMGa7p9Ca4VQIeHlJiPKV1kc8.css.pagespeed.cf.fw1A0X786e.css\" media=\"only screen and (max-width:767px)\"/>\n"
# DEBUG:                                 "<style media=\"all\">@font-face{font-family:'RopaSoftPro-Regular';src:url(sites/default/files/fontyourface/local_fonts/RopaSoftPro_Regular-normal-normal/RopaSoftPro-Regular-webfont.eot);src:url(sites/default/files/fontyourface/local_fonts/RopaSoftPro_Regular-normal-normal/RopaSoftPro-Regular-webfont.eot?#iefix) format(\"embedded-opentype\"),url(sites/default/files/fontyourface/local_fonts/RopaSoftPro_Regular-normal-normal/RopaSoftPro-Regular-webfont.ttf) format(\"truetype\"),url(sites/default/files/fontyourface/local_fonts/RopaSoftPro_Regular-normal-normal/RopaSoftPro-Regular-webfont.woff) format(\"woff\"),url(sites/default/files/fontyourface/local_fonts/RopaSoftPro_Regular-normal-normal/RopaSoftPro-Regular-webfont.svg#ropa_soft_proregular) format(\"svg\");font-style:normal;font-weight:normal;}\n"
# DEBUG:                                 "</style>\n"
# DEBUG:                                 "  <script type=\"text/javascript\" src=\"http://fci.nust.na/sites/all/modules/respondjs/respondjs/lib/respond.min.js,qq0uot7.pagespeed.jm.t37PdnypD7.js\"></script>\n"
# DEBUG:                                 "<script type=\"text/javascript\" src=\"http://fci.nust.na/sites/default/files/js/js_hulMQeqjF8ve0NZMub5AoK8cNJYigyJDRVHqsNsO5gQ.js.pagespeed.jm.JcchohHVIK.js\"></script>\n"
# DEBUG:                                 "<script src=\"http://fci.nust.na/sites/default/files/js/js_R9UbiVw2xuTUI0GZoaqMDOdX0lrZtgX-ono8RVOUEVc.js+js_DZ9OptWXHyyB-5ymrRujq41g0768sMUyo_61ub2IB0I.js+js_xuT-FY0VijO-21CJbGVrHBiLrjMWg5S6s8LTvdDqwNc.js.pagespeed.jc.iaY0CKO2uz.js\"></script><script>eval(mod_pagespeed_lFCvEBbyy1);</script>\n"
# DEBUG:                                 "<script>eval(mod_pagespeed_BhIQ34sf_C);</script>\n"
# DEBUG:                                 "<script type=\"text/javascript\" src=\"//cdn.jsdelivr.net/qtip2/2.2.1/jquery.qtip.min.js\"></script>\n"
# DEBUG:                                 "<script>eval(mod_pagespeed_EFfoWo8mI6);</script>\n"
# DEBUG:                                 "<script type=\"text/javascript\">//<![CDATA[\n"
# DEBUG:                                 "(function(i,s,o,g,r,a,m){i[\"GoogleAnalyticsObject\"]=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,\"script\",\"https://www.google-analytics.com/analytics.js\",\"ga\");ga(\"create\",\"UA-57809938-5\",{\"cookieDomain\":\"auto\"});ga(\"set\",\"anonymizeIp\",true);ga(\"send\",\"pageview\");\n"
# DEBUG:                                 "//]]></script>\n"
# DEBUG:                                 "<script type=\"text/javascript\" src=\"http://fci.nust.na/sites/default/files/js/js_hJ8gBk9KcLdAdZNl6slJy36sFZIvZ1GB5dqeAgVEJ3I.js.pagespeed.jm.yA45rmN0Ro.js\"></script>\n"
# DEBUG:                                 "<script type=\"text/javascript\">//<![CDATA[\n"
# DEBUG:                                 "jQuery.extend(Drupal.settings,{\"basePath\":\"\\/\",\"pathPrefix\":\"\",\"ajaxPageState\":{\"theme\":\"educational\",\"theme_token\":\"j-ix93VmAWqoflnWN_7-nvobliVB-VVrK7QMZJpSZcY\",\"js\":{\"sites\\/all\\/modules\\/respondjs\\/respondjs\\/lib\\/respond.min.js\":1,\"sites\\/all\\/modules\\/jquery_update\\/replace\\/jquery\\/1.7\\/jquery.min.js\":1,\"misc\\/jquery.once.js\":1,\"misc\\/drupal.js\":1,\"sites\\/all\\/modules\\/admin_menu\\/admin_devel\\/admin_devel.js\":1,\"sites\\/all\\/libraries\\/colorbox\\/jquery.colorbox-min.js\":1,\"sites\\/all\\/modules\\/colorbox\\/js\\/colorbox.js\":1,\"sites\\/all\\/modules\\/colorbox\\/styles\\/default\\/colorbox_style.js\":1,\"\\/\\/cdn.jsdelivr.net\\/qtip2\\/2.2.1\\/jquery.qtip.min.js\":1,\"sites\\/all\\/modules\\/qtip\\/js\\/qtip.js\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/js\\/tb-megamenu-frontend.js\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/js\\/tb-megamenu-touch.js\":1,\"sites\\/all\\/modules\\/google_analytics\\/googleanalytics.js\":1,\"0\":1,\"sites\\/all\\/themes\\/educational\\/bootstrap\\/js\\/bootstrap.js\":1,\"sites\\/all\\/themes\\/educational\\/js\\/uikit.min.js\":1,\"sites\\/all\\/themes\\/educational\\/js\\/waypoints.js\":1,\"sites\\/all\\/themes\\/educational\\/js\\/educational.js\":1,\"sites\\/all\\/themes\\/educational\\/js\\/jquery.smooth-scroll.js\":1},\"css\":{\"modules\\/system\\/system.base.css\":1,\"modules\\/system\\/system.menus.css\":1,\"modules\\/system\\/system.messages.css\":1,\"modules\\/system\\/system.theme.css\":1,\"modules\\/comment\\/comment.css\":1,\"sites\\/all\\/modules\\/date\\/date_api\\/date.css\":1,\"sites\\/all\\/modules\\/date\\/date_popup\\/themes\\/datepicker.1.7.css\":1,\"sites\\/all\\/modules\\/date\\/date_repeat_field\\/date_repeat_field.css\":1,\"modules\\/field\\/theme\\/field.css\":1,\"modules\\/node\\/node.css\":1,\"modules\\/search\\/search.css\":1,\"modules\\/user\\/user.css\":1,\"modules\\/forum\\/forum.css\":1,\"sites\\/all\\/modules\\/views\\/css\\/views.css\":1,\"sites\\/all\\/modules\\/ckeditor\\/css\\/ckeditor.css\":1,\"sites\\/all\\/modules\\/colorbox\\/styles\\/default\\/colorbox_style.css\":1,\"sites\\/all\\/modules\\/ctools\\/css\\/ctools.css\":1,\"\\/\\/cdn.jsdelivr.net\\/qtip2\\/2.2.1\\/jquery.qtip.min.css\":1,\"sites\\/all\\/modules\\/qtip\\/css\\/qtip.css\":1,\"sites\\/all\\/modules\\/views_metro\\/css\\/metro.css\":1,\"sites\\/all\\/modules\\/views_metro\\/views_metro.css\":1,\"sites\\/all\\/modules\\/biblio\\/biblio.css\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/css\\/bootstrap.css\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/css\\/base.css\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/css\\/default.css\":1,\"sites\\/all\\/modules\\/tb_megamenu\\/css\\/compatibility.css\":1,\"sites\\/all\\/libraries\\/fontawesome\\/css\\/font-awesome.css\":1,\"sites\\/all\\/themes\\/educational\\/bootstrap\\/css\\/bootstrap.css\":1,\"sites\\/all\\/themes\\/educational\\/bootstrap\\/css\\/bootstrap-theme.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/html.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/base.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/page.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/block.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/view.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/menu.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/off-canvas.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/animate.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/ie8-and-below.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/ie.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/screens\\/tablet.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/screens\\/common.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/screens\\/vertical_tablet.css\":1,\"sites\\/all\\/themes\\/educational\\/css\\/screens\\/mobile.css\":1,\"public:\\/\\/fontyourface\\/local_fonts\\/RopaSoftPro_Regular-normal-normal\\/stylesheet.css\":1}},\"colorbox ...
# DEBUG:                                 "//]]></script>\n"
# DEBUG:                                 "  <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->\n"
# DEBUG:                                 "    <!--[if lt IE 9]>\n"
# DEBUG:                                 "      <script src=\"https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js\"></script>\n"
# DEBUG:                                 "      <script src=\"https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js\"></script>\n"
# DEBUG:                                 "\t  <script src=\"https://css3-mediaqueries-js.googlecode.com/svn/trunk/css3-mediaqueries.js\"></script>\n"
# DEBUG:                                 "    <![endif]-->\n"
# DEBUG:                                 "</head>\n"
# DEBUG:                                 "<body class=\"html not-front not-logged-in one-sidebar sidebar-second page-list-all-staff animation-zoomIn\">\n"
# DEBUG:                                 "  <div id=\"skip-link\">\n"
# DEBUG:                                 "    <a href=\"#main-content\" class=\"element-invisible element-focusable\">Skip to main content</a>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "      <div id=\"mobile-menu\" class=\"uk-offcanvas\">\n"
# DEBUG:                                 "      <div class=\"uk-offcanvas-bar\">\n"
# DEBUG:                                 "          <div class=\"region region-panel-mobile-menu\">\n"
# DEBUG:                                 "    <div id=\"block-system-main-menu--2\" class=\"block block-system block-menu\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <ul class=\"menu\"><li class=\"first leaf\"><a href=\"/\">Home</a></li>\n"
# DEBUG:                                 "<li class=\"collapsed\"><a href=\"/?q=about-faculty\">About</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=courses\">Programmes</a></li>\n"
# DEBUG:                                 "<li class=\"collapsed\"><a href=\"/?q=departments\">Departments</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=faculty-research-strategies-2014-2018\">Research</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=publications\">Publications</a></li>\n"
# DEBUG:                                 "<li class=\"collapsed\"><a href=\"/?q=students\">Students</a></li>\n"
# DEBUG:                                 "<li class=\"leaf active-trail\"><a href=\"/?q=list-all-staff\" class=\"active-trail active\">Staff</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=content/contacts\">Contact</a></li>\n"
# DEBUG:                                 "<li class=\"last leaf\"><a href=\"/?q=faqs\">FAQs</a></li>\n"
# DEBUG:                                 "</ul>  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "      </div>\n"
# DEBUG:                                 "    </div>\n"
# DEBUG:                                 "    <div id=\"page\">\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    <header id=\"header\" class=\"header section\">\n"
# DEBUG:                                 "      <div class=\"container\">\n"
# DEBUG:                                 "        <div>\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "\t\t  <a href=\"javascript:;\" class=\"off-canvas-toggle navbar-canvas-toggle icon-toggle hidden-lg\" data-uk-offcanvas=\"{target:'#mobile-menu'}\">\n"
# DEBUG:                                 "        <i class=\"fa fa-bars\"></i>\n"
# DEBUG:                                 "      </a>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "\t\t    <div class=\"region region-header\">\n"
# DEBUG:                                 "    <div id=\"block-menu-menu-headline-link\" class=\"block block-menu\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <ul class=\"menu\"><li class=\"first leaf\"><a href=\"http://www.nust.na\" class=\"edustation-logout fa fa-bars\" target=\"_blank\">NUST Home</a></li>\n"
# DEBUG:                                 "<li class=\"last leaf\"><a href=\"http://www.nust.na/?q=schools\" class=\"edustation-logout fa fa-bars\" target=\"_blank\">Other Faculties</a></li>\n"
# DEBUG:                                 "</ul>  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "                                                    <a href=\"/\" title=\"Back To Home\" rel=\"home\" id=\"logo\">\n"
# DEBUG:                                 "                  <img src=\"http://fci.nust.na/sites/all/themes/educational/xlogo-2.png.pagespeed.ic.cZUKHxy8BQ.png\" alt=\"Back To Home\"/>\n"
# DEBUG:                                 "                </a>\n"
# DEBUG:                                 "                                    \n"
# DEBUG:                                 "          \n"
# DEBUG:                                 "          \n"
# DEBUG:                                 "        </div>\n"
# DEBUG:                                 "      </div>\n"
# DEBUG:                                 "    </header>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \t\n"
# DEBUG:                                 "\t      \n"
# DEBUG:                                 "\t  <nav class=\"collapse navbar-collapse width\" id=\"main-menu-inner\">\n"
# DEBUG:                                 "\t\t<div class=\"container\">\n"
# DEBUG:                                 "\t\t    <div class=\"region region-main-menu\">\n"
# DEBUG:                                 "    <div id=\"block-tb-megamenu-main-menu\" class=\"block block-tb-megamenu\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <div class=\"tb-megamenu tb-megamenu-main-menu\">\r\n"
# DEBUG:                                 "  <ul class=\"tb-megamenu-nav nav level-0 items-11\">\n"
# DEBUG:                                 "  <li data-id=\"221\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Home          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"547\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega dropdown\">\n"
# DEBUG:                                 "  <a href=\"/?q=about-faculty\" class=\"dropdown-toggle\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    About          <span class=\"caret\"></span>\n"
# DEBUG:                                 "          </a>\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"\" class=\"tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child\">\n"
# DEBUG:                                 "  <div class=\"mega-dropdown-inner\">\n"
# DEBUG:                                 "    <div class=\"tb-megamenu-row row-fluid\">\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"12\" data-hidewcol=\"0\" id=\"tb-megamenu-column-1\" class=\"tb-megamenu-column span12  mega-col-nav\">\n"
# DEBUG:                                 "  <div class=\"tb-megamenu-column-inner mega-inner clearfix\">\n"
# DEBUG:                                 "        <ul class=\"tb-megamenu-subnav mega-nav level-1 items-4\">\n"
# DEBUG:                                 "  <li data-id=\"1113\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=message-dean\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Message from the Dean          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"549\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=news\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    News          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"550\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=events\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Events and Announcements          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1074\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=gallery\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Gallery          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "</ul>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1081\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=courses\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Programmes          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1129\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega dropdown\">\n"
# DEBUG:                                 "  <a href=\"/?q=departments\" class=\"dropdown-toggle\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Departments          <span class=\"caret\"></span>\n"
# DEBUG:                                 "          </a>\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"\" class=\"tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child\">\n"
# DEBUG:                                 "  <div class=\"mega-dropdown-inner\">\n"
# DEBUG:                                 "    <div class=\"tb-megamenu-row row-fluid\">\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"12\" data-hidewcol=\"0\" id=\"tb-megamenu-column-2\" class=\"tb-megamenu-column span12  mega-col-nav\">\n"
# DEBUG:                                 "  <div class=\"tb-megamenu-column-inner mega-inner clearfix\">\n"
# DEBUG:                                 "        <ul class=\"tb-megamenu-subnav mega-nav level-1 items-2\">\n"
# DEBUG:                                 "  <li data-id=\"1223\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=department/informatics\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Informatics          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1204\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=department/computer-science\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Computer Science          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "</ul>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1115\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=faculty-research-strategies-2014-2018\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Research          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1255\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=publications\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Publications          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1352\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega dropdown\">\n"
# DEBUG:                                 "  <a href=\"/?q=students\" class=\"dropdown-toggle\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Students          <span class=\"caret\"></span>\n"
# DEBUG:                                 "          </a>\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"\" class=\"tb-megamenu-submenu dropdown-menu mega-dropdown-menu nav-child\">\n"
# DEBUG:                                 "  <div class=\"mega-dropdown-inner\">\n"
# DEBUG:                                 "    <div class=\"tb-megamenu-row row-fluid\">\n"
# DEBUG:                                 "  <div data-class=\"\" data-width=\"12\" data-hidewcol=\"0\" id=\"tb-megamenu-column-3\" class=\"tb-megamenu-column span12  mega-col-nav\">\n"
# DEBUG:                                 "  <div class=\"tb-megamenu-column-inner mega-inner clearfix\">\n"
# DEBUG:                                 "        <ul class=\"tb-megamenu-subnav mega-nav level-1 items-2\">\n"
# DEBUG:                                 "  <li data-id=\"1354\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=fci-society\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    FCI Society          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1353\" data-level=\"2\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-2 mega\">\n"
# DEBUG:                                 "  <a href=\"http://students.nust.na/\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Student Intranet          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "</ul>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1184\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega active\">\n"
# DEBUG:                                 "  <a href=\"/?q=list-all-staff\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Staff          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"553\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=content/contacts\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    Contact          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "<li data-id=\"1068\" data-level=\"1\" data-type=\"menu_item\" data-class=\"\" data-xicon=\"\" data-caption=\"\" data-alignsub=\"\" data-group=\"0\" data-hidewcol=\"0\" data-hidesub=\"0\" class=\"tb-megamenu-item level-1 mega\">\n"
# DEBUG:                                 "  <a href=\"/?q=faqs\" class=\"\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    FAQs          </a>\n"
# DEBUG:                                 "  </li>\n"
# DEBUG:                                 "</ul>\n"
# DEBUG:                                 "</div>\r\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "\t\t</div>\n"
# DEBUG:                                 "\t  </nav>      \n"
# DEBUG:                                 "\t\n"
# DEBUG:                                 "              <section id=\"main-title\" class=\"main-title\">\n"
# DEBUG:                                 "        <div class=\"container\">\n"
# DEBUG:                                 "          \n"
# DEBUG:                                 "          \n"
# DEBUG:                                 "                          <h1 class=\"title\" id=\"page-title\">Staff</h1>\n"
# DEBUG:                                 "                                      <h2 class=\"page__slogan title\" id=\"page-slogan\">List Staff</h2>\n"
# DEBUG:                                 "                        \n"
# DEBUG:                                 "                  </div>\n"
# DEBUG:                                 "      </section>\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "          <div id=\"top-container\" class=\"top-container\">\n"
# DEBUG:                                 "\t\t<div class=\"container\">\n"
# DEBUG:                                 "\t      <nav id=\"top-content-inner\">\n"
# DEBUG:                                 "\t\t      <div class=\"region region-top-content\">\n"
# DEBUG:                                 "    <div id=\"block-menu-menu-staff-views\" class=\"block block-menu menu-view-type animation\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <ul class=\"menu\"><li class=\"first leaf active-trail\"><a href=\"/?q=list-all-staff\" class=\"fa fa-list active-trail active\">List</a></li>\n"
# DEBUG:                                 "<li class=\"last leaf\"><a href=\"/?q=list-staff-grid\" class=\"fa fa-th-large\">Grid</a></li>\n"
# DEBUG:                                 "</ul>  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "\t\t  </nav>\n"
# DEBUG:                                 "\t\t</div>\n"
# DEBUG:                                 "      </div>\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    <section id=\"main\" class=\"main section\">\n"
# DEBUG:                                 "      <div class=\"container\">\n"
# DEBUG:                                 "        <div class=\"row\">\n"
# DEBUG:                                 "                   \n"
# DEBUG:                                 "    \t\t  <div id=\"content\" class=\"column col-md-9\">\n"
# DEBUG:                                 "    \t\t    \n"
# DEBUG:                                 "    \t\t        \t\t        \t\t        \t\t        \t\t    \n"
# DEBUG:                                 "    \t\t\t\t\t\t\t\t\n"
# DEBUG:                                 "\t\t\t\t  <div class=\"region region-content\">\n"
# DEBUG:                                 "    <div id=\"block-system-main\" class=\"block block-system\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <div class=\"view view-grid-staff view-id-grid_staff view-display-id-page_2 view-images animation view-dom-id-5a7b7440a795cd4ed24d1ee123db475b\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "      <div class=\"view-filters\">\n"
# DEBUG:                                 "      <form action=\"/?q=list-all-staff\" method=\"get\" id=\"views-exposed-form-grid-staff-page-2\" accept-charset=\"UTF-8\"><div>  <input type=\"hidden\" name=\"q\" value=\"list-all-staff\"/>\n"
# DEBUG:                                 "<div class=\"views-exposed-form\">\n"
# DEBUG:                                 "  <div class=\"views-exposed-widgets clearfix\">\n"
# DEBUG:                                 "          <div id=\"edit-field-staff-department-tid-wrapper\" class=\"views-exposed-widget views-widget-filter-field_staff_department_tid\">\n"
# DEBUG:                                 "                  <label for=\"edit-field-staff-department-tid\">\n"
# DEBUG:                                 "            Department           </label>\n"
# DEBUG:                                 "                        <div class=\"views-widget\">\n"
# DEBUG:                                 "          <div class=\"form-item form-type-select form-item-field-staff-department-tid\">\n"
# DEBUG:                                 " <select id=\"edit-field-staff-department-tid\" name=\"field_staff_department_tid\" class=\"form-select\"><option value=\"All\" selected=\"selected\">- Any -</option><option value=\"112\">FCI Society</option><option value=\"26\">Computer Science</option><option value=\"27\">Informatics</option></select>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "        </div>\n"
# DEBUG:                                 "              </div>\n"
# DEBUG:                                 "          <div id=\"edit-field-job-title-tid-wrapper\" class=\"views-exposed-widget views-widget-filter-field_job_title_tid\">\n"
# DEBUG:                                 "                  <label for=\"edit-field-job-title-tid\">\n"
# DEBUG:                                 "            Job Title           </label>\n"
# DEBUG:                                 "                        <div class=\"views-widget\">\n"
# DEBUG:                                 "          <div class=\"form-item form-type-select form-item-field-job-title-tid\">\n"
# DEBUG:                                 " <select id=\"edit-field-job-title-tid\" name=\"field_job_title_tid\" class=\"form-select\"><option value=\"All\" selected=\"selected\">- Any -</option><option value=\"122\">Acting: Deputy Head of Department</option><option value=\"121\">Acting: Head of Department</option><option value=\"128\">Associate Dean: Research and Innovation</option><option value=\"127\">Associate Dean: Teaching and Learning</option><option value=\"129\">Deputy Head of Department: Software Engineering</option><option value=\"130\">Deputy Head of Department: System Administration &amp; Computer Networking</option><option value=\"88\">Adjunct Professor</option><option value=\"108\">Receptionist</option><option value=\"113\">FCI Society</option><option value=\"125\">-International Student Representative</option><option value=\"115\">-President</option><option value=\"124\">-Public Relations Officer (High School Affairs)</option><option value=\"126\">-Treasurer</option><option value=\"116\">-Vice President</option><option value=\"117\">-Secretary General</option><option value=\"118\">-Public Relations Officer (External)</option><option value=\"119\">-Public Relations Officer (internal)</option><option value=\"120\">-Public Relations Officer</option><option value=\"107\">Senior Lab Technician</option><option value=\"61\">Associate Dean</option><option value=\"60\">Dean</option><option value=\"72\">Deputy Director</option><option value=\"63\">Deputy Head of Department</option><option value=\"70\">Director</option><option value=\"73\">Grant Administrator</option><option value=\"62\">Head of Department</option><option value=\"69\">Junior Lecturer</option><option value=\"71\">Lab Technician</option><option value=\"68\">Lecturer</option><option value=\"76\">Professor</option><option value=\"65\">Secretary</option><option value=\"64\">Secretary: Office of the Dean</option><option value=\"67\">Senior Lecturer</option><option value=\"74\">Tutor</option><option value=\"66\">Associate Professor</option></select>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "        </div>\n"
# DEBUG:                                 "              </div>\n"
# DEBUG:                                 "          <div id=\"edit-field-full-name-value-wrapper\" class=\"views-exposed-widget views-widget-filter-field_full_name_value\">\n"
# DEBUG:                                 "                  <label for=\"edit-field-full-name-value\">\n"
# DEBUG:                                 "            Full name           </label>\n"
# DEBUG:                                 "                        <div class=\"views-widget\">\n"
# DEBUG:                                 "          <div class=\"form-item form-type-textfield form-item-field-full-name-value\">\n"
# DEBUG:                                 " <input type=\"text\" id=\"edit-field-full-name-value\" name=\"field_full_name_value\" value=\"\" size=\"30\" maxlength=\"128\" class=\"form-text\"/>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "        </div>\n"
# DEBUG:                                 "              </div>\n"
# DEBUG:                                 "                    <div class=\"views-exposed-widget views-submit-button\">\n"
# DEBUG:                                 "      <input type=\"submit\" id=\"edit-submit-grid-staff\" name=\"\" value=\"Search Staff\" class=\"form-submit\"/>    </div>\n"
# DEBUG:                                 "          <div class=\"views-exposed-widget views-reset-button\">\n"
# DEBUG:                                 "        <input type=\"submit\" id=\"edit-reset\" name=\"op\" value=\"Clear\" class=\"form-submit\"/>      </div>\n"
# DEBUG:                                 "      </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "</div></form>    </div>\n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "      <div class=\"view-content\">\n"
# DEBUG:                                 "      <table class=\"views-table cols-0 table table-bordered table-hover table-condensed table-0\">\n"
# DEBUG:                                 "      <tbody>\n"
# DEBUG:                                 "      <tr class=\"odd views-row-first\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-field-full-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/anicia-peters\">Prof.  Anicia Peters</a>        </td>\n"
# ...
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <div class=\"profile\" typeof=\"sioc:UserAccount\" about=\"/?q=users/jose-quenum\">\n"
# DEBUG:                                 "    <div class=\"user-picture\">\n"
# DEBUG:                                 "    <a href=\"/?q=users/jose-quenum\" title=\"View user profile.\" class=\"active\"><img typeof=\"foaf:Image\" src=\"http://fci.nust.na/sites/default/files/pictures/xpicture-33-1453723781.jpg.pagespeed.ic.KOBBU-VyX7.jpg\" alt=\"Jose Quenum&#039;s picture\" title=\"Jose Quenum&#039;s picture\"/></a>  </div>\n"
# DEBUG:                                 "<div class=\"collapsible group-user-info speed-fast effect-none\">\n"
# DEBUG:                                 "      <h3><span class=\"field-group-format-toggler\">User Info</span></h3>\n"
# DEBUG:                                 "      <div class=\"field-group-format-wrapper\" style=\"display: block;\"><div class=\"field field-name-field-full-name field-type-text field-label-hidden h5\"><div class=\"field-items\"><div class=\"field-item even\">Prof. Jose Quenum</div></div></div><div class=\"field field-name-field-job-title field-type-taxonomy-term-reference field-label-hidden h5\"><div class=\"field-items\"><div class=\"field-item even\"><a href=\"/?q=staff/associate-professor\" typeof=\"skos:Concept\" property=\"rdfs:label skos:prefLabel\" datatype=\"\">Associate Professor</a></div></div></div><div class=\"field field-name-field-staff-department field-type-taxonomy-term-reference field-label-above h5\"><div class=\"field-label\">Department:&nbsp;</div><div class=\"field-items\"><div class=\"field-item even\"><a href=\"/?q=departments/computer-science\" typeof=\"skos:Concept\" property=\"rdfs:label skos:prefLabel\" datatype=\"\">Computer Science</a></div></div></div></div></div><div class=\"collapsible group-user-description field-group-div speed-fast effect-none\">\n"
# DEBUG:                                 "      <h2><span class=\"field-group-format-toggler\">Staff Details</span></h2>\n"
# DEBUG:                                 "      <div class=\"field-group-format-wrapper\" style=\"display: block;\"><div class=\"field field-name-field-telephone-number field-type-text field-label-inline clearfix\"><div class=\"field-label\">Telephone Number:&nbsp;</div><div class=\"field-items\"><div class=\"field-item even\">+264 61 207 2235</div></div></div><div class=\"field field-name-field-disguise-email field-type-text field-label-inline clearfix\"><div class=\"field-label\">Email:&nbsp;</div><div class=\"field-items\"><div class=\"field-item even\">jquenum [at] nust [dot] na</div></div></div><div class=\"field field-name-field-office-location field-type-text field-label-inline clearfix\"><div class=\"field-label\">Office Location:&nbsp;</div><div class=\"field-items\"><div class=\"field-item even\">Information Technology House</div></div></div><div class=\"field field-name-field-user-description field-type-text-long field-label-above\"><div class=\"field-label\">Qualification:&nbsp;</div><div class=\"field-items\"><div class=\"field-item even\">PhD. Comp. Sci. (UPMC), MSc. Comp. Sci. (Univ. Paris Dauphine), BSc. (Hons) Comp. Sci. (Univ. Paris Dauphine), BSc. Comp. Sci. (Univ. Nationale du Bénin)</div></div></div></div></div></div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "    \t\t  </div>\n"
# DEBUG:                                 "         \n"
# DEBUG:                                 "                      <aside id=\"sidebar-second\" class=\"sidebar col-md-3\">\n"
# DEBUG:                                 "                <div class=\"region region-sidebar-second\">\n"
# DEBUG:                                 "    <div id=\"block-views-side-links-staff-block--2\" class=\"block block-views\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    <h2>All Staff</h2>\n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <div class=\"view view-side-links-staff view-id-side_links_staff view-display-id-block view-dom-id-2493115ac13320340965284e485b5445\">\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "      <div class=\"view-content\">\n"
# DEBUG:                                 "      <table class=\"views-table cols-0 table table-striped table-hover table-0 table-0\">\n"
# DEBUG:                                 "      <tbody>\n"
# DEBUG:                                 "      <tr class=\"odd views-row-first\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/j%C3%BCrgen-sieck\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/j%C3%BCrgen-sieck\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Jürgen Sieck</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"even\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/jose-quenum\" title=\"View user profile.\" class=\"username active\" xml:lang=\"\" about=\"/?q=users/jose-quenum\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Jose Quenum</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"odd\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/hippolyte-muyingi\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/hippolyte-muyingi\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Hippolyte Muyingi</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"even\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/heike-winschiers\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/heike-winschiers\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Heike Winschiers</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"odd\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/guy-lusilao\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/guy-lusilao\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Guy Lusilao</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"even\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/dharm-singh-jat\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/dharm-singh-jat\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Dharm Singh Jat</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"odd\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/anicia-peters\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/anicia-peters\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Anicia Peters</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"even\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/hilya-h-shivute\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/hilya-h-shivute\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Hilya H Shivute</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"odd\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/uakomba-mbasuva\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/uakomba-mbasuva\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Uakomba Mbasuva</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "      <tr class=\"even views-row-last\">\n"
# DEBUG:                                 "              <td class=\"views-field views-field-name\">\n"
# DEBUG:                                 "          <a href=\"/?q=users/teresia-ankome\" title=\"View user profile.\" class=\"username\" xml:lang=\"\" about=\"/?q=users/teresia-ankome\" typeof=\"sioc:UserAccount\" property=\"foaf:name\" datatype=\"\">Teresia Ankome</a>        </td>\n"
# DEBUG:                                 "          </tr>\n"
# DEBUG:                                 "    </tbody>\n"
# DEBUG:                                 "</table>\n"
# DEBUG:                                 "    </div>\n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "      <div class=\"item-list\"><ul class=\"pager\"><li class=\"pager-previous first\">&nbsp;</li>\n"
# DEBUG:                                 "<li class=\"pager-current\">1 of 6</li>\n"
# DEBUG:                                 "<li class=\"pager-next last\"><a title=\"Go to next page\" href=\"/?q=users/jose-quenum&amp;page=1\">next ›</a></li>\n"
# DEBUG:                                 "</ul></div>  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "  \n"
# DEBUG:                                 "</div>  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "            </aside>\n"
# DEBUG:                                 "                  </div>\n"
# DEBUG:                                 "      </div>\n"
# DEBUG:                                 "    </section>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "          <footer id=\"footer\" class=\"section\">\n"
# DEBUG:                                 "        <div class=\"container\">\n"
# DEBUG:                                 "            <div class=\"region region-footer\">\n"
# DEBUG:                                 "    <div id=\"block-menu-menu-footer-menu\" class=\"block block-menu footer-menu animation\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <ul class=\"menu\"><li class=\"first leaf\"><a href=\"/?q=faculty-research-strategies-2014-2018\">Research</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=publications\">Publications</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=courses\">Programmes Offered</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"/?q=list-all-staff\">Staff</a></li>\n"
# DEBUG:                                 "<li class=\"leaf\"><a href=\"http://www.nust.na/?q=vacancies\" target=\"_blank\">Job Opportunities</a></li>\n"
# DEBUG:                                 "<li class=\"last leaf\"><a href=\"/?q=privacy-policy\">Privacy Policy</a></li>\n"
# DEBUG:                                 "</ul>  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "<div id=\"block-block-5\" class=\"block block-block logo-footer animation\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <p><a href=\"http://www.nust.na\" rel=\"home\" title=\"Namibia University of Science and Technology\" target=\"_blank\"><img alt=\"NUST\" src=\"/sites/default/files/images/xclean-shield.png.pagespeed.ic.EsbiFigPeI.png\"></a></p>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "<div id=\"block-block-2\" class=\"block block-block logo-footer animation\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <address>\n"
# DEBUG:                                 "<p>13 Jackson Kaujeua Street, Windhoek, Namibia . Private Bag 13388 Windhoek, Namibia<br/>\n"
# DEBUG:                                 "TEL: +264-61-207-9111 / FAX: +264-61-207-2444</p>\n"
# DEBUG:                                 "</address>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "<div id=\"block-block-3\" class=\"block block-block edusation-copyright\">\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "    \n"
# DEBUG:                                 "  <div class=\"content\">\n"
# DEBUG:                                 "    <p>Copyright © 2019 <a href=\"http://www.nust.na\" target=\"_blank\">Namibia University of Science and Technology</a>. All rights reserved. <a href=\"?q=disclaimer\">Disclaimer.</a> Developed and Maintained by <a href=\"http://www.nust.na/?q=university-administration/dict/about-dict\" target=\"_blank\">DICT</a>.</p>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "</div>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "          <!--?php print $feed_icons; ?-->\n"
# DEBUG:                                 "        </div>\n"
# DEBUG:                                 "      </footer>\n"
# DEBUG:                                 "        \n"
# DEBUG:                                 "\t<a title=\"Back to Top\" class=\"btn-btt\" href=\"#Top\">Back to Top</a>\n"
# DEBUG:                                 "  </div>\n"
# DEBUG:                                 "\n"
# DEBUG:                                 "  </body>\n"
# {"type":"image","alt":"Professor Prof. Jose Quenum","info":"http://fci.nust.na/sites/default/files/pictures/xpicture-33-1453723781.jpg.pagespeed.ic.KOBBU-VyX7.jpg"}
# ┌ Info: /pass_val 200
# └ @ Genie.Router C:\Users\Dell Pro\.julia\packages\Genie\9ipqT\src\Router.jl:148
